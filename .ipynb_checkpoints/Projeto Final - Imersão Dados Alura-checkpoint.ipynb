# %% [markdown]
# # Imersão Dados Alura:
#
# Esse jupyter notebook tem a intenção de resumir tudo que foi mostrado nas aulas da Imersão de Dados da Alura feita em Maio de 2022. Tentarei deixar o máximo explicado, para que seja possível entender e compreender as ideias por trás dos comandos.
#
# De forma geral começamos de uma base de dados que nos foi dada, e queremos ao máximo extrair informações que podem nos ser uteis. Daí partimos para a criação de gráficos, dando uma extensão maior ao conhecimento sobre qual gráfico usar e por fim partimos para a união de trabalhos com mais banco de dados (datasets) e suas uniões, começando a trabalhar com predições com machine learning.

# %% [markdown]
# #  Aula1: Começando do básico

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10006         Rua Manuel Onha, , 514        Vila Oratório  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas  \
# 0          1000        4          8      6
# 1           496        4          4      4
# ...

# %%
# Outra forma de saber a quantidade de registros.
dados.shape
# Out:
# (10008, 8)

# %%
dados.sample(10)
# Out:
#                                 Rua               Bairro     Cidade  Metragem  \
# 2043                            NaN      Vila Tramontano  São Paulo       270
# 8169      Rua Deputado Euvaldo Lodi       Retiro Morumbi  São Paulo      1250
# 4679                            NaN  Jardim Santa Helena  São Paulo       350
# 1234             Rua Murtinho Nobre              Butantã  São Paulo       320
# 1757           Rua Mariano Procópio       Vila Monumento  São Paulo       205
# 9556                            NaN       Jardim América  São Paulo       755
# 3028               Rua Laura Vicuna             Vila Ida  São Paulo       900
# 2705                     Rua Dalton         Alto da Lapa  São Paulo       237
# 3309  Rua Cláudio Henrique de Paula            Vila Rica  São Paulo       125
# 2467             Rua Domingos Lopes           Campo Belo  São Paulo       150
#
#       Quartos  Banheiros  Vagas                                  Valor
# ...

# %%
dados["Bairro"].value_counts()
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
# Froma de conseguir informações sobre as colunas

dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %% [markdown]
# Colunas que estão com o Dtype como 'object' não podemos fazer a média dos valores, pois tem conteúdo que não são identificados como números! Só poderemos fazer média inicialmente com vagas, banheiros, quartos e banheiros!
#
# Para coluna como valor primeiro precisaremos tratar os dados...

# %%
#Pegando a média das colunas numéricas.
dados.mean(numeric_only=True)
# Out:
# Metragem     442.300659
# Quartos        3.483114
# Banheiros      3.879097
# Vagas          4.097222
# dtype: float64

# %%
#Pegando a média de uma coluna específica.
dados["Quartos"].mean()
# Out:
# 3.4831135091926457

# %%
#Média da metragem do Bairro da vila Mariana
#Primeiramente, tem a vila Mariana?
sum(dados["Bairro"] == "Vila Mariana")
# Out:
# 184

# %% [markdown]
# O que a gente fez foi ver se tem imóveis na Vila Mariana, a ideia é _dados.bairro_ == "Vila Mariana" retornar uma series que retorna um booleano para cada indice, onde 0 é falso e 1 é verdadeiro, e fazendo a soma de todos esse valores, retornará quantos imóveis terá nesse bairro.

# %%
#Fazendo uma variável guardar esse valor:
imv_vila_mariana = (dados["Bairro"] == "Vila Mariana")
imv_vila_mariana
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
imoveis_vila_mariana = dados[imv_vila_mariana]
imoveis_vila_mariana
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
#Média da Metragem dos imóveis da Vila Mariana
imoveis_vila_mariana["Metragem"].mean()
# Out:
# 233.6195652173913

# %%
#Quantidade de imóveis por Bairro
num_imoveis_bairro = dados["Bairro"].value_counts()
num_imoveis_bairro
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
#Vendo de forma proporcional
num_imoveis_bairro_porc = dados["Bairro"].value_counts(normalize = True)*100
num_imoveis_bairro_porc
# Out:
# Alto de Pinheiros     4.091637
# Jardim Guedala        4.031613
# Jardim Paulista       3.091236
# Brooklin Paulista     2.470988
# Jardim Europa         2.400960
#                         ...
# Jardim das Imbuias    0.010004
# Vila Represa          0.010004
# Vila Nancy            0.010004
# Sítio Represa         0.010004
# Vila Invernada        0.010004
# Name: Bairro, Length: 701, dtype: float64

# %%
num_imoveis_bairro.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Muito difícil de entender o que está acontecendo pois tendo 701 bairros tornam os nomes muito comprimidos na parte inferior dos gráficos.

# %% [markdown]
# Podemos tentar fazer o mesmo com o head():

# %%
num_imoveis_bairro.head(10).plot.bar()
# Out:
# <AxesSubplot:>

# %%
#Desafio: Média da metragem por bairro (Paulo)


#Desafio: 2 formas de selecionar os dados por bairro (Consultar os métodos na documentação dos pandas)(Thiago)


#Desafio: Explorar alguns gráficos na documentação e aplicas na demais colunas do DF, tentar colocar alguma conclusão (Thiago)


#Desafio: Pegar outros estatísticas dos dados, média, mediana, min e máx.


#Desafio: Descobrir quais são os Bairros que não tem nome de Rua?

# %% [markdown]
# ## Desafio1: Média da metragem por bairro

# %%
Metragem_por_bairro = dados.groupby(['Bairro']).Metragem.mean()
Metragem_por_bairro
# Out:
# Bairro
# Aclimação            253.056818
# Alto da Boa Vista    418.875000
# Alto da Lapa         294.337209
# Alto da Mooca        270.050000
# Alto de Pinheiros    433.444988
#                         ...
# Vila Água Funda      152.200000
# Água Branca          191.000000
# Água Fria            165.416667
# Água Funda           139.000000
# Água Rasa            340.250000
# Name: Metragem, Length: 701, dtype: float64

# %%
##Fazer para todas as colunas de número:
dados.groupby(['Bairro']).mean()
# Out:
#                      Metragem   Quartos  Banheiros     Vagas
# Bairro
# Aclimação          253.056818  3.318182   3.079545  2.909091
# Alto da Boa Vista  418.875000  4.125000   5.125000  4.625000
# Alto da Lapa       294.337209  3.151163   3.790698  3.906977
# Alto da Mooca      270.050000  3.300000   2.600000  3.650000
# Alto de Pinheiros  433.444988  3.938875   4.838631  5.004890
# ...                       ...       ...        ...       ...
# Vila Água Funda    152.200000  2.600000   2.200000  2.600000
# Água Branca        191.000000  3.153846   3.076923  2.461538
# Água Fria          165.416667  2.833333   3.416667  2.500000
# Água Funda         139.000000  3.000000   2.500000  2.000000
# Água Rasa          340.250000  3.500000   3.250000  5.250000
#
# [701 rows x 4 columns]

# %% [markdown]
# ## Desafio2: Duas formas de selecionar os dados por bairro

# %%
forma1 = dados.query("Bairro == 'Vila Mariana'")
forma1
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
forma2 = dados.loc[dados['Bairro'] == 'Vila Mariana']
forma2
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %% [markdown]
# ## Desafio3: Explorar alguns gráficos na documentação

# %% [markdown]
# Explorando gráficos da documentação do pandas.
# Não necessariamente todos irão funcionar, pois não se encaixam com a ideia dos números, nem irão tentar

# %%
dados["Quartos"].plot.box()
# Out:
# <AxesSubplot:>

# %%
dados.query("Metragem < 5000")["Metragem"].plot.box()
# Out:
# <AxesSubplot:>

# %%
dados["Quartos"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## Desafio4: Pegar outras características dos dados, média, mediana, min e máx.

# %% [markdown]
# Vendo através da documentação do pandas, encontrei o método describe(), que retorna de forma geral todos os valores que queríamos.
#
# Através deles podemos chegar a algumas conclusões também!

# %%
dados.describe()
# Out:
#             Metragem       Quartos     Banheiros         Vagas
# count   10008.000000  10008.000000  10008.000000  10008.000000
# mean      442.300659      3.483114      3.879097      4.097222
# std      7515.379389      1.064200      1.988467      2.824014
# min        10.000000      1.000000      1.000000      1.000000
# 25%       173.000000      3.000000      2.000000      2.000000
# 50%       290.000000      3.000000      4.000000      4.000000
# 75%       460.250000      4.000000      5.000000      5.000000
# max    750000.000000     16.000000     40.000000     50.000000

# %% [markdown]
# Vamos começar com a análise da coluna de Metragem:
# Olhando em cima dos valores mínimo e máximo podemos olhar que são valores bem discrepantes. Temos um desvio padrão bem alto também, provavelmente causado pelo valor máximo, e podemos dizer que é ele, pois quando olhando os quartis e a mediana, vemos que 50% dos valores estão abaixo do 290m², e 75% estão abaixo de 460m², logo esse valor máximo realmente é algo fora da curva.
#
# De forma similar acontece com as outras colunas.

# %% [markdown]
# ## Desafio5: Descobrir quais são os Bairros que não tem nome de rua

# %% [markdown]
# Esse trabalho eu vi através do trabalho de outros colegas que ajudaram a ter esse inspiração:
#
# Utilizei o método de isnull().

# %%
bairros_sem_rua = dados[dados["Rua"].isnull()]
bairros_sem_rua["Bairro"]
# Out:
# 3                         Jardim Morumbi
# 11                      Jardim Luzitânia
# 31                        Parque da Lapa
# 56      Chácara Santo Antônio (Zona Sul)
# 57                        Jardim Guedala
#                       ...
# 9963                   Jardim Petrópolis
# 9989                Parque Alves de Lima
# 9991                        Vila Formosa
# 9995                       Jardim Leonor
# 9999                   Jardim Petrópolis
# Name: Bairro, Length: 3434, dtype: object

# %% [markdown]
# </details>

# %% [markdown]
# # Aula2: Tratamento de dados e primeiros gráficos

# %%
dados["Valor"][0]
# Out:
# 'R$ 7.000.000'

# %%
dados["Valor"][0].split()
# Out:
# ['R$', '7.000.000']

# %%
#Mas podemos encontrar situações com mais sujeiras além desse R$ que encontramos:
dados.sample(10)
# Out:
#                                      Rua             Bairro     Cidade  \
# 8217                       Rua Primavera    Jardim Paulista  São Paulo
# 6442  Rua Visconde de Aguiar Toledo, 50      Vila Congonhas  São Paulo
# 5924    Avenida Diógenes Ribeiro de Lima  Alto de Pinheiros  São Paulo
# 9203              Rua Padre Luís Soriano   Jardim da Glória  São Paulo
# 8927                                 NaN            Morumbi  São Paulo
# 5525                       Rua Acarituba        Santo Amaro  São Paulo
# 3587                                 NaN      Jardim Europa  São Paulo
# 5065                     Rua Tomé Portes  Brooklin Paulista  São Paulo
# 2555                     Rua Cordisburgo      Jardim Leonor  São Paulo
# 5598                 Rua Agostinho Gomes           Ipiranga  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas  \
# 8217       355        3          3      4
# 6442       195        3          4      2
# 5924       195        3          3      5
# ...

# %% [markdown]
# Como por exemplo achar na coluna Valor _\n /Mês_...

# %%
#Uma forma de fazer a separação ainda mais interessante:
dados["Valor"].str.split()
# Out:
# 0          [R$, 7.000.000]
# 1          [R$, 3.700.000]
# 2            [R$, 380.000]
# 3            [R$, 685.000]
# 4            [R$, 540.000]
#                ...
# 10003        [R$, 665.000]
# 10004      [R$, 2.300.000]
# 10005      [R$, 1.050.000]
# 10006    [R$, 2.200, /Mês]
# 10007        [R$, 270.000]
# Name: Valor, Length: 10008, dtype: object

# %% [markdown]
# Agora separamos em espaços da string! Mais fácil de visualizar as sujeiras da coluna Valor.

# %%
#Adicionando mais uma característica:
dados["Valor"].str.split(expand = True)
# Out:
#         0          1     2
# 0      R$  7.000.000  None
# 1      R$  3.700.000  None
# 2      R$    380.000  None
# 3      R$    685.000  None
# 4      R$    540.000  None
# ...    ..        ...   ...
# 10003  R$    665.000  None
# 10004  R$  2.300.000  None
# 10005  R$  1.050.000  None
# 10006  R$      2.200  /Mês
# 10007  R$    270.000  None
#
# [10008 rows x 3 columns]

# %% [markdown]
# Mostra de forma mais clara a separação da string do valor. Agora tendo essas colunas separadas, 0, 1 e 2, podemos trabalhar em cima delas. Como por exemplo:

# %%
#Pegando quantas strings tem dentro da coluna 0 da tabela acima.
dados["Valor"].str.split(expand = True)[0].unique()
# Out:
# array(['R$'], dtype=object)

# %%
#Quantos preços tem no total da tabela dados?
len(dados["Valor"].str.split(expand = True)[1].unique())
# Out:
# 1038

# %% [markdown]
# Tem um total de 1038 preços diferenciados nessa tabela de 10008 registros! O pessoal não varia tanto os preços...

# %%
dados["Valor"].str.split(expand = True)[2].unique()
# Out:
# array([None, '/Mês', '/Ano', '/Dia'], dtype=object)

# %% [markdown]
# Agora para essa coluna, vemos que tem 4 tipos de valores no resultado da última parte da string da coluna Valor.
# Que devem esta associados a alugueis, contudo não queremos trabalhar com isso, somente com vendas.

# %%
#Não consegui anotar - pegar isso depois:

dados[["Valor", "Bairro"]]
# Out:
#                                       Valor              Bairro
# 0                              R$ 7.000.000   Planalto Paulista
# 1                              R$ 3.700.000  Jardim dos Estados
# 2                                R$ 380.000     Jardim Reimberg
# 3                                R$ 685.000      Jardim Morumbi
# 4                                R$ 540.000               Mooca
# ...                                     ...                 ...
# 10003                            R$ 665.000          Vila Sofia
# 10004                          R$ 2.300.000     Bosque da Saúde
# 10005                          R$ 1.050.000       Vila da Saúde
# 10006  R$ 2.200\n                      /Mês       Vila Oratório
# 10007                            R$ 270.000         Vila Alpina
#
# [10008 rows x 2 columns]

# %%
#Criando novas colunas do Dataframe dados

dados[["Moeda","Valor_do_anuncio", "Tipo_de_anuncio"]] = dados["Valor"].str.split(expand = True)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_do_anuncio  \
# 0        4          8      6  R$ 7.000.000    R$        7.000.000
# 1        4          4      4  R$ 3.700.000    R$        3.700.000
# 2        4          3      2    R$ 380.000    R$          380.000
# 3        3          2      4    R$ 685.000    R$          685.000
# 4        3          2      2    R$ 540.000    R$          540.000
#
#   Tipo_de_anuncio
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None

# %%
dados[dados["Tipo_de_anuncio"].isnull()]
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda  \
# 0          1000        4          8      6  R$ 7.000.000    R$
# ...

# %%
dados[dados["Tipo_de_anuncio"].isnull()]["Tipo_de_anuncio"].unique()
# Out:
# array([None], dtype=object)

# %%
#Atualizamos o valor dados para tirar os tipo de anúncio que são alugueis, mas na verdade não é bom fazer isso, é melhor
#Criar outra variável que guarda essa nova informação sem perder a anterior

dados_venda = dados[dados["Tipo_de_anuncio"].isnull()]
dados_venda
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda  \
# 0          1000        4          8      6  R$ 7.000.000    R$
# ...

# %%
dados_venda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rua               6107 non-null   object
#  1   Bairro            9146 non-null   object
#  2   Cidade            9156 non-null   object
#  3   Metragem          9156 non-null   int64
#  4   Quartos           9156 non-null   int64
#  5   Banheiros         9156 non-null   int64
#  6   Vagas             9156 non-null   int64
#  7   Valor             9156 non-null   object
#  8   Moeda             9156 non-null   object
#  9   Valor_do_anuncio  9156 non-null   object
#  10  Tipo_de_anuncio   0 non-null      object
# dtypes: int64(4), object(7)
# memory usage: 858.4+ KB

# %% [markdown]
# O valor do anúncio ainda não é um inteiro, então não podemos fazer a media disso.
# Mas se fizermos um replace...

# %%
dados_venda["Valor_do_anuncio"].str.replace(".","").astype(float)
# Out:
# /tmp/ipykernel_711/3249315765.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados_venda["Valor_do_anuncio"].str.replace(".","").astype(float)
# 0        7000000.0
# 1        3700000.0
# 2         380000.0
# 3         685000.0
# 4         540000.0
#            ...
# 10002    1500000.0
# 10003     665000.0
# 10004    2300000.0
# 10005    1050000.0
# 10007     270000.0
# Name: Valor_do_anuncio, Length: 9156, dtype: float64

# %%
dados_venda["Valor_do_anuncio_float"] = dados_venda["Valor_do_anuncio"].str.replace(".","").astype(float)
# Out:
# /tmp/ipykernel_711/3931964697.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados_venda["Valor_do_anuncio_float"] = dados_venda["Valor_do_anuncio"].str.replace(".","").astype(float)
# /tmp/ipykernel_711/3931964697.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_venda["Valor_do_anuncio_float"] = dados_venda["Valor_do_anuncio"].str.replace(".","").astype(float)

# %%
dados_venda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rua                     6107 non-null   object
#  1   Bairro                  9146 non-null   object
#  2   Cidade                  9156 non-null   object
#  3   Metragem                9156 non-null   int64
#  4   Quartos                 9156 non-null   int64
#  5   Banheiros               9156 non-null   int64
#  6   Vagas                   9156 non-null   int64
#  7   Valor                   9156 non-null   object
#  8   Moeda                   9156 non-null   object
#  9   Valor_do_anuncio        9156 non-null   object
#  10  Tipo_de_anuncio         0 non-null      object
#  11  Valor_do_anuncio_float  9156 non-null   float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 929.9+ KB

# %%
dados_venda["Valor_do_anuncio_float"].mean()
# Out:
# 3052202.9554390563

# %%
dados_venda["Valor_do_anuncio_float"].plot.hist(bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#Pega todos as colunas com valor numérico e retorna os valores estatísticos de cada coluna:
dados_venda.describe()
# Out:
#             Metragem      Quartos    Banheiros        Vagas  \
# count    9156.000000  9156.000000  9156.000000  9156.000000
# mean      434.416230     3.446811     3.797073     3.960135
# std      7856.422978     1.048944     1.967873     2.601022
# min        10.000000     1.000000     1.000000     1.000000
# 25%       168.000000     3.000000     2.000000     2.000000
# 50%       276.000000     3.000000     4.000000     4.000000
# 75%       450.000000     4.000000     5.000000     5.000000
# max    750000.000000    16.000000    40.000000    50.000000
#
#        Valor_do_anuncio_float
# count            9.156000e+03
# mean             3.052203e+06
# std              3.944208e+06
# min              1.300000e+04
# 25%              8.900000e+05
# 50%              1.800000e+06
# 75%              3.500000e+06
# max              6.500000e+07

# %%
dados_venda["Valor_do_anuncio_float"].max()
# Out:
# 65000000.0

# %%
#Retorna a precisão diferente
pd.set_option("display.precision",2)
dados_venda.describe()
# Out:
#         Metragem  Quartos  Banheiros    Vagas  Valor_do_anuncio_float
# count    9156.00  9156.00    9156.00  9156.00                9.16e+03
# mean      434.42     3.45       3.80     3.96                3.05e+06
# std      7856.42     1.05       1.97     2.60                3.94e+06
# min        10.00     1.00       1.00     1.00                1.30e+04
# 25%       168.00     3.00       2.00     2.00                8.90e+05
# 50%       276.00     3.00       4.00     4.00                1.80e+06
# 75%       450.00     4.00       5.00     5.00                3.50e+06
# max    750000.00    16.00      40.00    50.00                6.50e+07

# %%
#Outra forma de display
pd.set_option("display.float_format", lambda x: '%.2f' % x)
dados_venda.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_do_anuncio_float
# count   9156.00  9156.00    9156.00 9156.00                 9156.00
# mean     434.42     3.45       3.80    3.96              3052202.96
# std     7856.42     1.05       1.97    2.60              3944208.19
# min       10.00     1.00       1.00    1.00                13000.00
# 25%      168.00     3.00       2.00    2.00               890000.00
# 50%      276.00     3.00       4.00    4.00              1800000.00
# 75%      450.00     4.00       5.00    5.00              3500000.00
# max   750000.00    16.00      40.00   50.00             65000000.00

# %%
dados_venda.describe(include = "all")
# Out:
#                       Rua             Bairro     Cidade  Metragem  Quartos  \
# count                6107               9146       9156   9156.00  9156.00
# unique               3006                697          1       NaN      NaN
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo       NaN      NaN
# freq                   24                369       9156       NaN      NaN
# mean                  NaN                NaN        NaN    434.42     3.45
# std                   NaN                NaN        NaN   7856.42     1.05
# min                   NaN                NaN        NaN     10.00     1.00
# 25%                   NaN                NaN        NaN    168.00     3.00
# 50%                   NaN                NaN        NaN    276.00     3.00
# 75%                   NaN                NaN        NaN    450.00     4.00
# max                   NaN                NaN        NaN 750000.00    16.00
#
#         Banheiros   Vagas         Valor Moeda Valor_do_anuncio  \
# ...

# %%
dados_venda[["Rua", "Bairro", "Cidade"]].describe()
# Out:
#                       Rua             Bairro     Cidade
# count                6107               9146       9156
# unique               3006                697          1
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo
# freq                   24                369       9156

# %%
#Histograma com seaborn
sns.set()
plt.figure(figsize=(10,8))
hist1 = sns.histplot(data = dados_venda,
                    x = "Valor_do_anuncio_float",
                    kde = True)
hist1.set_title("Histograma Valor Imóvel", fontsize = 18)
plt.xlim((-50,10000000))
plt.show()

# %% [markdown]
# ## Desafio1: Criar uma escala de valores em milhões

# %%
dados_venda_esp = dados_venda.query("Valor_do_anuncio_float < 10000000.00")
sns.set()
plt.figure(figsize=(15,8))
hist1 = sns.histplot(data = dados_venda_esp,
                    x = "Valor_do_anuncio_float",
                    kde = True,
                    bins = 50)
hist1.set_title("Histograma Qtd de Imóveis X Preço do Imóvel")
hist1.set_xlabel("Preço do anúncio")
hist1.set_ylabel("Quantidade de imóveis")
plt.xticks([0,500000,1000000,1500000,2500000,5000000,7500000], rotation=90)
plt.show()

# %% [markdown]
# ## Desafio2: Deixar o gráfico do histograma de valores mais redondo;
# Melhorar os índices do eixo horizontal, e o nome dos eixos.
# Melhorar o título.
#
# Deixar ele realmente um gráfico mais claro, legível e possível de ser compreendido, labels, título, cores, escala.

# %%
dados_venda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rua                     6107 non-null   object
#  1   Bairro                  9146 non-null   object
#  2   Cidade                  9156 non-null   object
#  3   Metragem                9156 non-null   int64
#  4   Quartos                 9156 non-null   int64
#  5   Banheiros               9156 non-null   int64
#  6   Vagas                   9156 non-null   int64
#  7   Valor                   9156 non-null   object
#  8   Moeda                   9156 non-null   object
#  9   Valor_do_anuncio        9156 non-null   object
#  10  Tipo_de_anuncio         0 non-null      object
#  11  Valor_do_anuncio_float  9156 non-null   float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 929.9+ KB

# %%
dados_venda_esp = dados_venda.query("Valor_do_anuncio_float < 20000000.00")
sns.set()
plt.figure(figsize=(10,8))
hist1 = sns.histplot(data = dados_venda_esp,
                    x = "Valor_do_anuncio_float",
                    kde = True,
                    bins = 100)
hist1.set_title("Histograma Qtd de Imóveis X Preço do Imóvel")
hist1.set_xlabel("Preço do anúncio")
hist1.set_xticklabels(["-1","0","2500000","5000000","7500000","10000000","12500000","15000000","17500000","20000000"], rotation=-45)
hist1.set_ylabel("Quantidade de imóveis")
hist1
# Out:
# /tmp/ipykernel_711/1146782781.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   hist1.set_xticklabels(["-1","0","2500000","5000000","7500000","10000000","12500000","15000000","17500000","20000000"], rotation=-45)
# <AxesSubplot:title={'center':'Histograma Qtd de Imóveis X Preço do Imóvel'}, xlabel='Preço do anúncio', ylabel='Quantidade de imóveis'>

# %% [markdown]
# ## Desafio3: O preço do metro quadrado(m²) por bairro. Colocar isso num gráfico para comparação entre preços. Deixando isso claro.

# %%
dados_venda["preco_m2"] = dados_venda["Valor_do_anuncio_float"]/dados_venda["Metragem"]
# Out:
# /tmp/ipykernel_711/3517042410.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_venda["preco_m2"] = dados_venda["Valor_do_anuncio_float"]/dados_venda["Metragem"]

# %%
# Agora aqui podemos ver o preço do metro quadrado por imóvel, basta agora separarmos por Bairro e fazer a média, assim 
# com feito no desafio do primeiro dia.

dados_venda.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_do_anuncio  \
# 0        4          8      6  R$ 7.000.000    R$        7.000.000
# 1        4          4      4  R$ 3.700.000    R$        3.700.000
# 2        4          3      2    R$ 380.000    R$          380.000
# 3        3          2      4    R$ 685.000    R$          685.000
# 4        3          2      2    R$ 540.000    R$          540.000
#
#   Tipo_de_anuncio  Valor_do_anuncio_float  preco_m2
# 0            None              7000000.00   7000.00
# ...

# %%
tabela_m2_media = dados_venda.groupby("Bairro").mean()
tabela_m2_media
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  \
# Bairro
# Aclimação            246.16     3.27       3.04   2.91
# Alto da Boa Vista    418.88     4.12       5.12   4.62
# Alto da Lapa         299.25     3.15       3.85   4.00
# Alto da Mooca        270.05     3.30       2.60   3.65
# Alto de Pinheiros    429.85     3.94       4.83   4.95
# ...                     ...      ...        ...    ...
# Vila Água Funda      152.20     2.60       2.20   2.60
# Água Branca          173.58     3.08       3.25   2.25
# Água Fria            165.42     2.83       3.42   2.50
# Água Funda           139.00     3.00       2.50   2.00
# Água Rasa            186.17     2.67       2.00   3.67
#
#                    Valor_do_anuncio_float  preco_m2
# Bairro
# Aclimação                      1763200.01   7656.17
# Alto da Boa Vista              2391250.00   5849.57
# Alto da Lapa                   2083168.75   7606.73
# Alto da Mooca                  1184170.00   5691.74
# ...

# %%
tabela_m2_media["preco_m2"].describe()
# Out:
# count     697.00
# mean     5056.53
# std      3846.68
# min        78.38
# 25%      3344.24
# 50%      4545.45
# 75%      5861.79
# max     80000.00
# Name: preco_m2, dtype: float64

# %%
plt.figure(figsize=(10,8))
hist2 = sns.histplot(data = tabela_m2_media,
                    x = tabela_m2_media["preco_m2"],
                    kde = True)
plt.xlim((-10, 10000))
# Out:
# (-10.0, 10000.0)

# %% [markdown]
# Isso aqui mostra em quantidade de bairros que estão com o preço do metro quadrado agrupado, ele quer que eu explicite. Não é um histograma que ele quer.

# %%
m2_media = pd.Series(data = tabela_m2_media["preco_m2"])
m2_media.sort_values(axis = 0, ascending = False,inplace = True)

# %%
#m2_media.plot.bar()

#Fazer isso é tentar plotar um gráfico de barras com aproximadamente 700 colunas, então não é uma boa ideia

# %%
#Podemos ordenar os valores obtidos e pegar os n primeiros dados de nossa escolha
m2_media.head(20).plot.bar()
# Out:
# <AxesSubplot:xlabel='Bairro'>

# %% [markdown]
# Então ordenamos e vendo dessa forma, tomamos que tem um bairro com um valor discrepante, podemos analisar os registros desse bairro:

# %%
dados_venda.loc[dados_venda["Bairro"] == "Vila Guaca"]
# Out:
#               Rua      Bairro     Cidade  Metragem  Quartos  Banheiros  Vagas  \
# 9603  Rua Pestana  Vila Guaca  São Paulo        10        3          2      2
#
#            Valor Moeda Valor_do_anuncio Tipo_de_anuncio  \
# 9603  R$ 800.000    R$          800.000            None
#
#       Valor_do_anuncio_float  preco_m2
# 9603               800000.00  80000.00

# %% [markdown]
# Então na verdade essa discrepância é causada pelo valor extremo do preço e sua metragem ser mínima. Então podemos dizer que esse registro é algum erro ou algo fora da curva, para todos os casos.

# %%
#Podemos querer trabalhar em cima de achar o melhor valor de preço por metragem.
m2_media.sort_values(axis=0, ascending = True, inplace = True)
m2_media.head(10).plot.bar()
# Out:
# <AxesSubplot:xlabel='Bairro'>

# %% [markdown]
# Novamente chegamos a um caso extremo, podemos novamente analisar como estão os registros desse bairro:

# %%
dados_venda.loc[dados_venda["Bairro"]=="Sítio Represa"]
# Out:
#                          Rua         Bairro     Cidade  Metragem  Quartos  \
# 6600  Rua Benedito Felizardo  Sítio Represa  São Paulo     37000        4
#
#       Banheiros  Vagas         Valor Moeda Valor_do_anuncio Tipo_de_anuncio  \
# 6600          2      4  R$ 2.900.000    R$        2.900.000            None
#
#       Valor_do_anuncio_float  preco_m2
# 6600              2900000.00     78.38

# %% [markdown]
# Novamente um caso que é discrepante em relação ao resto, contudo é possível perder dimensão do valor por serem valores muito grandes.

# %% [markdown]
# Esse casos extremos seriam tipo de informações que seriam limpadas do conjunto de dados por trazerem casos que não devem ser de interesse geral de ser inclusos, uma vez que podem estar trazendo um dado desnecessário.

# %% [markdown]
# ## Desafio4: Exploração do Galeritas e achar uma visualização diferente para um gráfico interessante e chegar a alguma conclusão que tenha valor.

# %%
## Algum momento utilizarei o Galeritas.

# %% [markdown]
# ## Desafio5: Pesquisar uma visualização para analisar os quartis, mediana e outliers.

# %%
#Para a melhorar a análise dos quartis e outliers, utilizaremos de boxplot
box1 = sns.boxplot(data = dados_venda[["Vagas","Banheiros","Quartos"]])
box1.figure.set_size_inches(12,8)
box1
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Aula3: Gráficos, Time Series e Análise Exploratória

# %% [markdown]
# Começando a aula fazendo um dos desafios da aula passada!
# Faremos o desafio3: Do preço do metro quadrado por Bairro.

# %%
# Esse foi o modo que eu fiz, deixarei ele no formato de comentário para não preencher novamente o dataframe com os mesmos dados.

#dados_venda["Valor_m2"] = dados_venda["Valor_do_anuncio_float"]/dados_venda["Metragem"]
#dados_venda

# %%
#dados_venda.groupby("Bairro").mean()

#Temos que tomar cuidado que não podemos tomar só fazer isso, pois tem as nuâncias de que não é todo o metro quadrado que 
#tem o mesmo valor que o outro, a valorização dele pode ser definida de várias formas, seja pela geolocalização, 
# pelos recursos em volta dele, além de quantidade de quartos, banheiros, e vagas de garagem. Não é tão simples assim.
#Mas vamos pensar de outra forma agora

# %%
#Vamos somar todos os valores de preço  e dividir pela metragem
dados_bairro = dados_venda.groupby("Bairro").sum()

# %%
dados_bairro["Valor_m2_bairro"] = dados_bairro["Valor_do_anuncio_float"]/dados_bairro["Metragem"]
dados_bairro
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  \
# Bairro
# Aclimação             19447      258        240    230
# Alto da Boa Vista      3351       33         41     37
# Alto da Lapa          23940      252        308    320
# Alto da Mooca          5401       66         52     73
# Alto de Pinheiros    158616     1453       1782   1827
# ...                     ...      ...        ...    ...
# Vila Água Funda         761       13         11     13
# Água Branca            2083       37         39     27
# Água Fria              1985       34         41     30
# Água Funda              278        6          5      4
# Água Rasa              1117       16         12     22
#
#                    Valor_do_anuncio_float   preco_m2  Valor_m2_bairro
# Bairro
# Aclimação                    139292801.00  604837.39          7162.69
# Alto da Boa Vista             19130000.00   46796.55          5708.74
# Alto da Lapa                 166653500.00  608538.25          6961.30
# ...

# %%
#Comparando com o resultado da outra forma
tabela_m2_media
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  \
# Bairro
# Aclimação            246.16     3.27       3.04   2.91
# Alto da Boa Vista    418.88     4.12       5.12   4.62
# Alto da Lapa         299.25     3.15       3.85   4.00
# Alto da Mooca        270.05     3.30       2.60   3.65
# Alto de Pinheiros    429.85     3.94       4.83   4.95
# ...                     ...      ...        ...    ...
# Vila Água Funda      152.20     2.60       2.20   2.60
# Água Branca          173.58     3.08       3.25   2.25
# Água Fria            165.42     2.83       3.42   2.50
# Água Funda           139.00     3.00       2.50   2.00
# Água Rasa            186.17     2.67       2.00   3.67
#
#                    Valor_do_anuncio_float  preco_m2
# Bairro
# Aclimação                      1763200.01   7656.17
# Alto da Boa Vista              2391250.00   5849.57
# Alto da Lapa                   2083168.75   7606.73
# Alto da Mooca                  1184170.00   5691.74
# ...

# %% [markdown]
# Podemos ver que o Bairro Aclimação toma valores diferentes! Que genial.

# %% [markdown]
# Agora que estamos vendo os bairros como índice, não podemos acessar eles como coluna da forma convencional, temos que primeiro difenir a coluna que queremos, ou teremos que trabahar com o loc.

# %%
dados_bairro.loc["Vila Mariana"]
# Out:
# Metragem                     39079.00
# Quartos                        573.00
# Banheiros                      547.00
# Vagas                          499.00
# Valor_do_anuncio_float   299326000.00
# preco_m2                   1337323.16
# Valor_m2_bairro               7659.51
# Name: Vila Mariana, dtype: float64

# %%
dados_bairro.loc["Vila Mariana"]["Valor_m2_bairro"]
# Out:
# 7659.510222881855

# %%
#Ou podemos tirar o loc fazendo o trabalho em cima do invertendo os nomes:
dados_bairro["Valor_m2_bairro"]["Vila Mariana"]
# Out:
# 7659.510222881855

# %% [markdown]
# E os gráficos? Não podemos colocar todos os gráficos juntos, teremos que pegar alguns casos, talvez os 10 bairros mais frequentes.
#
# Então vamos pegar os 10 bairros mais frequentes primeiro:

# %%
bairros10 = dados_venda["Bairro"].value_counts()[:10].index
bairros10
# Out:
# Index(['Alto de Pinheiros', 'Jardim Guedala', 'Jardim Paulista',
#        'Brooklin Paulista', 'Jardim Europa', 'Pacaembu', 'Vila Madalena',
#        'Cidade Jardim', 'Planalto Paulista', 'Jardim Leonor'],
#       dtype='object')

# %%
dados_bairro.reset_index(inplace = True)
dados_bairro
# Out:
#                 Bairro  Metragem  Quartos  Banheiros  Vagas  \
# 0            Aclimação     19447      258        240    230
# 1    Alto da Boa Vista      3351       33         41     37
# 2         Alto da Lapa     23940      252        308    320
# 3        Alto da Mooca      5401       66         52     73
# 4    Alto de Pinheiros    158616     1453       1782   1827
# ..                 ...       ...      ...        ...    ...
# 692    Vila Água Funda       761       13         11     13
# 693        Água Branca      2083       37         39     27
# 694          Água Fria      1985       34         41     30
# 695         Água Funda       278        6          5      4
# 696          Água Rasa      1117       16         12     22
#
#      Valor_do_anuncio_float   preco_m2  Valor_m2_bairro
# 0              139292801.00  604837.39          7162.69
# 1               19130000.00   46796.55          5708.74
# 2              166653500.00  608538.25          6961.30
# ...

# %%
#Fazendo o gráfico de barra com os 10 bairros mais frequentes
data_bar1 = dados_bairro.query("Bairro in @bairros10")
plt.figure(figsize=(10,8))
bar1 = sns.barplot(x= "Bairro",
                   y= "Valor_m2_bairro",
                   data = data_bar1)
bar1.tick_params(axis='x',rotation = -45)

# %%
#Vamos plotar um boxplot para esse 10 bairros
plt.figure(figsize=(10,8))
box2 = sns.boxplot(data = dados_venda.query("Bairro in @bairros10"),
                  x="Bairro",
                  y = "Valor_do_anuncio_float")
box2.tick_params(axis='x',rotation = -45)
plt.show()

# %%
plt.figure(figsize=(10,8))
box3 = sns.boxplot(data = dados_venda.query("Bairro in @bairros10 & Metragem < 3000"),
                  x="Bairro",
                  y = "Metragem")
box3.tick_params(axis='x',rotation = -45)
plt.show()

# %%
#Nova base de dados:

# %% [markdown]
# Arquivo para documentação do IBGE para entender como trabalhar com essa base de dados.
#
# [Aqui](https://drive.google.com/file/d/1WVTqfKtHOOk5X1AWaSOn6NLaO7cix2m4/view).

# %% [markdown]
# ## Desafio1: Tentar vincular dados do IBGE com os dados iniciais
# Identificar a leitura do encode, aprender a separação dos dados e tentar associar os valores.

# %%
ibge_url = "https://gist.githubusercontent.com/tgcsantos/85f8c7b0a2edbc3e27fcad619b37d886/raw/a4954781e6bca9cb804062a3eea0b3b84679daf4/Basico_SP1.csv"
dados_ibge = pd.read_csv(ibge_url,sep=";",thousands=".",decimal=",",encoding="ISO-8859-1")  #Pegando o material da aula seguinte
dados_ibge.dropna(how='all', axis=1,inplace=True)
dados_ibge.head()
# Out:
#          Cod_setor  Cod_Grandes Regiï¿½es Nome_Grande_Regiao  Cod_UF  \
# 0  355030801000001                      3   Regiï¿½o Sudeste      35
# 1  355030801000002                      3   Regiï¿½o Sudeste      35
# 2  355030801000003                      3   Regiï¿½o Sudeste      35
# 3  355030801000004                      3   Regiï¿½o Sudeste      35
# 4  355030801000005                      3   Regiï¿½o Sudeste      35
#
#    Nome_da_UF   Cod_meso                  Nome_da_meso  Cod_micro  \
# 0  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 1  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 2  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 3  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 4  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
#
#   Nome_da_micro  Cod_RM  ... V003  V004    V005       V006    V007       V008  \
# ...

# %% [markdown]
# ## Desafio2: Tratamento de Outliers, e comparar os novos resultados.

# %% [markdown]
# Passos:
#  - Identificar valores dos outliers de cada uma das colunas;
#  - Gerar um novo ou sobreescrever o DataFrame com os outliers removidos;
#  - Comparar dados estatísticos;

# %% [markdown]
# ## Desafio3: Agrupar por mais de uma categoria e realizar as análises.

# %% [markdown]
# ## Desafio4: Organização de Notebook.

# %% [markdown]
# Considere feito!

# %% [markdown]
# # Aula4: Missão impossível-Cruzando base de dados

# %% [markdown]
# Ver e rever essa aula algumas vezes.

# %%
dados_ibge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18363 entries, 0 to 18362
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Cod_setor              18363 non-null  int64
#  1   Cod_Grandes Regiï¿½es  18363 non-null  int64
#  2   Nome_Grande_Regiao     18363 non-null  object
#  3   Cod_UF                 18363 non-null  int64
#  4   Nome_da_UF             18363 non-null  object
#  5   Cod_meso               18363 non-null  int64
#  6   Nome_da_meso           18363 non-null  object
#  7   Cod_micro              18363 non-null  int64
#  8   Nome_da_micro          18363 non-null  object
#  9   Cod_RM                 18363 non-null  int64
#  10  Nome_da_RM             18363 non-null  object
#  11  Cod_municipio          18363 non-null  int64
#  12  Nome_do_municipio      18363 non-null  object
#  13  Cod_distrito           18363 non-null  int64
# ...

# %%
dados_endereco = pd.read_csv("../../base/enderecos.csv")
dados_endereco.head()
# Out:
# /tmp/ipykernel_711/3791705025.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   dados_endereco = pd.read_csv("../../base/enderecos.csv")
#   tipo_logr                      logr_nome  \
# 0       Rua               Armando Silveira
# 1       Rua       João Antônio Vasconcelos
# 2       Rua  Prefeito Agenor Barcelos Feio
# 3       Rua                Sebastião Gomes
# 4       Rua            Marquês do Alegrete
#
#                                    logr_compl numero            bairro  \
# 0                        Rua Armando Silveira    NaN            Divisa
# 1  Rua João Antônio Vasconcelos - até 627/628    627           Amizade
# 2           Rua Prefeito Agenor Barcelos Feio    NaN          Registro
# 3             Rua Sebastião Gomes - até 59/60     59          Registro
# 4                     Rua Marquês do Alegrete    NaN  Parque das Águas
#
#          nome_localidade sigla_uf         cep  latitude  longitude
# ...

# %%
dados_endereco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1113886 entries, 0 to 1113885
# Data columns (total 10 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   tipo_logr        1113559 non-null  object
#  1   logr_nome        1113566 non-null  object
#  2   logr_compl       1113567 non-null  object
#  3   numero           28810 non-null    object
#  4   bairro           1113546 non-null  object
#  5   nome_localidade  1093788 non-null  object
#  6   sigla_uf         1093788 non-null  object
#  7   cep              1093788 non-null  float64
#  8   latitude         1090660 non-null  float64
#  9   longitude        1090660 non-null  float64
# dtypes: float64(3), object(7)
# memory usage: 85.0+ MB

# %%
dados_endereco.shape
# Out:
# (1113886, 10)

# %%
dados_endereco_sp = dados_endereco.query("sigla_uf == 'SP'")
dados_endereco_sp.head()
# Out:
#        tipo_logr                 logr_nome  \
# 1            Rua  João Antônio Vasconcelos
# 413269       Rua                         A
# 413270       Rua                         A
# 413271       Rua                         A
# 413272       Rua              João Bandini
#
#                                         logr_compl numero  \
# 1       Rua João Antônio Vasconcelos - até 627/628    627
# 413269                                       Rua A    NaN
# 413270                                       Rua A    NaN
# 413271                                       Rua A    NaN
# 413272                            Rua João Bandini    NaN
#
#                         bairro nome_localidade sigla_uf         cep  latitude  \
# 1                      Amizade       Araçatuba       SP 16074320.00    -21.19
# 413269           Jardim Glória       Americana       SP 13468220.00    -22.76
# 413270        Jardim São Roque       Americana       SP 13469414.00    -22.74
# ...

# %%
dados_endereco_sp["rua"] = dados_endereco_sp["tipo_logr"] + " " + dados_endereco_sp["logr_nome"]
dados_endereco_sp["rua"] = dados_endereco_sp["rua"].str.lower().str.strip()
dados_endereco_sp.head()
# Out:
# /tmp/ipykernel_711/3223930911.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_endereco_sp["rua"] = dados_endereco_sp["tipo_logr"] + " " + dados_endereco_sp["logr_nome"]
# /tmp/ipykernel_711/3223930911.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_endereco_sp["rua"] = dados_endereco_sp["rua"].str.lower().str.strip()
#        tipo_logr                 logr_nome  \
# 1            Rua  João Antônio Vasconcelos
# 413269       Rua                         A
# ...

# %%
dados_venda["Rua"].str.extract(r'(^[\w ]+)')[:10]
# Out:
#                            0
# 0            Avenida Itacira
# 1  Rua Aurelia Perez Alvarez
# 2            Rua Alba Valdez
# 3                        NaN
# 4         Rua Tobias Barreto
# 5            Rua Graham Bell
# 6        Rua Francisco Paulo
# 7      Rua Guilherme Valente
# 8        Rua Sagrada Família
# 9                 Rua Tapaji

# %%
dados_venda["apenas_rua"] = dados_venda["Rua"].str.extract(r'(^[\w ]+)')
dados_venda["apenas_rua"] = dados_venda["apenas_rua"].str.lower().str.strip()
dados_venda.head()
# Out:
# /tmp/ipykernel_711/2467226979.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_venda["apenas_rua"] = dados_venda["Rua"].str.extract(r'(^[\w ]+)')
# /tmp/ipykernel_711/2467226979.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_venda["apenas_rua"] = dados_venda["apenas_rua"].str.lower().str.strip()
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# ...

# %%
dados_geo = pd.merge(left = dados_venda, right = dados_endereco_sp[["rua", "cep", "latitude", "longitude"]], how = "left",
                     left_on = "apenas_rua", right_on = "rua").drop_duplicates(subset=dados_venda.columns).query("cep > 0")
dados_geo
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 5      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 6                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 7                                 NaN      Jardim Morumbi  São Paulo
# 26           Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 89956                   Avenida Odila   Planalto Paulista  São Paulo
# 89958                      Rua Tapuçu          Vila Sofia  São Paulo
# 89959                   Rua Guararema     Bosque da Saúde  São Paulo
# 89976               Rua Estero Belaco       Vila da Saúde  São Paulo
# 89977      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda  \
# 0          1000        4          8      6  R$ 7.000.000    R$
# ...

# %%
dados_ibge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18363 entries, 0 to 18362
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Cod_setor              18363 non-null  int64
#  1   Cod_Grandes Regiï¿½es  18363 non-null  int64
#  2   Nome_Grande_Regiao     18363 non-null  object
#  3   Cod_UF                 18363 non-null  int64
#  4   Nome_da_UF             18363 non-null  object
#  5   Cod_meso               18363 non-null  int64
#  6   Nome_da_meso           18363 non-null  object
#  7   Cod_micro              18363 non-null  int64
#  8   Nome_da_micro          18363 non-null  object
#  9   Cod_RM                 18363 non-null  int64
#  10  Nome_da_RM             18363 non-null  object
#  11  Cod_municipio          18363 non-null  int64
#  12  Nome_do_municipio      18363 non-null  object
#  13  Cod_distrito           18363 non-null  int64
# ...

# %%
from shapely.geometry import Point
latitude = -23.56 	
longitude = -46.59
Point(longitude, latitude)

# %%
from shapely.geometry import Polygon
Polygon([[0, 0], [1, 0], [1, 1], [0, 1], [0, 0]])

# %%
Polygon([[0, 0], [1, 0], [1, 1], [0, 1], [0, 0]]).contains(Point(0.1,0.9))
# Out:
# True

# %%
import geopandas as gpd

# %%
setor_censo = gpd.read_file('../../base/35SEE250GC_SIR.shp')
setor_censo.head()
# Out:
#         ID       CD_GEOCODI    TIPO   CD_GEOCODS NM_SUBDIST CD_GEOCODD  \
# 0 98237.00  354100005000009  URBANO  35410000500       None  354100005
# 1 98232.00  354100005000004  URBANO  35410000500       None  354100005
# 2 98230.00  354100005000002  URBANO  35410000500       None  354100005
# 3 98229.00  354100005000001  URBANO  35410000500       None  354100005
# 4 98231.00  354100005000003  URBANO  35410000500       None  354100005
#
#      NM_DISTRIT CD_GEOCODM    NM_MUNICIP NM_MICRO                     NM_MESO  \
# 0  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
# 1  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
# 2  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
# 3  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
# 4  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
#
#      CD_GEOCODB  NM_BAIRRO  ID1  \
# 0  354100005001  Boqueirão    1
# ...

# %%
setor_censo.shape
# Out:
# (68296, 15)

# %%
setor_censo_sp = setor_censo[setor_censo.NM_MUNICIP == "SÃO PAULO"]
setor_censo_sp[setor_censo_sp.contains(Point(-46.63, -23.58))]
# Out:
#              ID       CD_GEOCODI    TIPO   CD_GEOCODS NM_SUBDIST CD_GEOCODD  \
# 60986 126568.00  355030890000080  URBANO  35503089000       None  355030890
#
#          NM_DISTRIT CD_GEOCODM NM_MUNICIP   NM_MICRO  \
# 60986  VILA MARIANA    3550308  SÃO PAULO  SÃO PAULO
#
#                           NM_MESO CD_GEOCODB NM_BAIRRO    ID1  \
# 60986  METROPOLITANA DE SÃO PAULO       None      None  60987
#
#                                                 geometry
# 60986  POLYGON ((-46.62618 -23.58169, -46.62863 -23.5...

# %%
#Linha de código que demanda tempo, depois ele importa o resultado dessa linha separadamente:

#dados_geo["Point"] = ""
#for i in dados_geo.index:
#    dados_geo["Point"][i] = Point(dados_geo["longitude"][i], dados_geo["latitude"][i])

#dados_geo['setor_censo'] = dados_geo["Point"][:10].map(
#    lambda x: setor_censo_sp.loc[setor_censo_sp.contains(x), 'CD_GEOCODI'].values
#).str[0]
#dados_geo

# %%
dados_geo = pd.read_csv("../../base/dados_geo.csv")
dados_geo.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3        Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 4                 Rua Graham Bell         Santo Amaro  São Paulo       440
#
#    Quartos  Banheiros  Vagas         Valor  Valor_anuncio  Tipo_anuncio  \
# 0        4          8      6  R$ 7.000.000     7000000.00           NaN
# 1        4          4      4  R$ 3.700.000     3700000.00           NaN
# 2        4          3      2    R$ 380.000      380000.00           NaN
# 3        3          2      2    R$ 540.000      540000.00           NaN
# 4        4          4      6  R$ 1.980.000     1980000.00           NaN
#
#    Valor_mm  Valor_m2                        rua        cep  latitude  \
# ...

# %%
dados_geo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5605 entries, 0 to 5604
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rua            5605 non-null   object
#  1   Bairro         5597 non-null   object
#  2   Cidade         5605 non-null   object
#  3   Metragem       5605 non-null   int64
#  4   Quartos        5605 non-null   int64
#  5   Banheiros      5605 non-null   int64
#  6   Vagas          5605 non-null   int64
#  7   Valor          5605 non-null   object
#  8   Valor_anuncio  5605 non-null   float64
#  9   Tipo_anuncio   0 non-null      float64
#  10  Valor_mm       5605 non-null   float64
#  11  Valor_m2       5605 non-null   float64
#  12  rua            5605 non-null   object
#  13  cep            5605 non-null   float64
#  14  latitude       5605 non-null   float64
#  15  longitude      5605 non-null   float64
#  16  Point          5605 non-null   object
# ...

# %%
dados_vendas_censo = pd.merge(left = dados_geo, right = dados_ibge, how = "left", left_on = "setor_censo", right_on = "Cod_setor")
dados_vendas_censo
# Out:
#                                  Rua              Bairro     Cidade  Metragem  \
# 0              Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1     Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                    Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3           Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 4                    Rua Graham Bell         Santo Amaro  São Paulo       440
# ...                              ...                 ...        ...       ...
# 5600                   Avenida Odila   Planalto Paulista  São Paulo       267
# 5601                      Rua Tapuçu          Vila Sofia  São Paulo        95
# 5602                   Rua Guararema     Bosque da Saúde  São Paulo       605
# 5603               Rua Estero Belaco       Vila da Saúde  São Paulo       205
# 5604      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo       122
#
# ...

# %%
dados_vendas_censo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5605 entries, 0 to 5604
# Data columns (total 51 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rua                    5605 non-null   object
#  1   Bairro                 5597 non-null   object
#  2   Cidade                 5605 non-null   object
#  3   Metragem               5605 non-null   int64
#  4   Quartos                5605 non-null   int64
#  5   Banheiros              5605 non-null   int64
#  6   Vagas                  5605 non-null   int64
#  7   Valor                  5605 non-null   object
#  8   Valor_anuncio          5605 non-null   float64
#  9   Tipo_anuncio           0 non-null      float64
#  10  Valor_mm               5605 non-null   float64
#  11  Valor_m2               5605 non-null   float64
#  12  rua                    5605 non-null   object
#  13  cep                    5605 non-null   float64
# ...

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(data = dados_vendas_censo, x="V005", y="Valor_m2")
# Out:
# <AxesSubplot:xlabel='V005', ylabel='Valor_m2'>

# %% [markdown]
# ## Desafio1: Realizar uma análise dos dados do IBGE por mapa, analisando a distribuição de renda
#
# Link para ajudar [aqui](https://medium.com/creditas-tech/dados-georreferenciados-explora%C3%A7%C3%A3o-e-visualiza%C3%A7%C3%A3o-com-python-edd51e7c53da).

# %% [markdown]
# ## Desafio2: Repassar a aula para entender melhor o que foi realizado.

# %% [markdown]
# ## Desafio3: Aprofundar a análise entre dados de vendas e renda.

# %% [markdown]
# ## Desafio4: Realizar a análise exploratória e encontrar variáveis relevantes para solução do problema.

# %% [markdown]
# # Aula5: Machine Learning

# %%
import numpy as np

# %%
pd.set_option("display.precision", 2)
pd.set_option("display.float_format", lambda x: '%.2f' %x)

dados_vendas_censo = dados_vendas_censo[['Rua', 'Bairro', "Cidade", "Metragem", "Quartos", "Banheiros",
                                        "Vagas", "Valor_anuncio", "Valor_mm", "Valor_m2", 
                                        "latitude", "longitude", "Situacao_setor", "V001", "V002", "V003",
                                        "V004", "V005", "V006","V007", "V008", "V009", "V010", "V011", "V012"]].dropna()
dados_vendas_censo
# Out:
#                                  Rua              Bairro     Cidade  Metragem  \
# 0              Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1     Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                    Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3           Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 4                    Rua Graham Bell         Santo Amaro  São Paulo       440
# ...                              ...                 ...        ...       ...
# 5599              Rua Pedro Teixeira        Vila Olímpia  São Paulo       157
# 5600                   Avenida Odila   Planalto Paulista  São Paulo       267
# 5601                      Rua Tapuçu          Vila Sofia  São Paulo        95
# 5603               Rua Estero Belaco       Vila da Saúde  São Paulo       205
# 5604      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo       122
#
# ...

# %%
plt.figure(figsize=(10,8))
box4 = sns.boxplot(data = dados_vendas_censo, y = "Valor_anuncio")
plt.show()

# %%
dados_vendas_censo.query("Valor_anuncio > 30000000 | Valor_anuncio < 100000")
# Out:
#                        Rua          Bairro     Cidade  Metragem  Quartos  \
# 54          Rua Inglaterra   Jardim Europa  São Paulo       200        3
# 89          Rua Inglaterra   Jardim Europa  São Paulo       756        5
# 1032  Praça Nicolau Scarpa  Jardim América  São Paulo      1200        4
# 3521    Rua Estados Unidos  Jardim América  São Paulo      1816        4
# 3896    Rua Estados Unidos  Jardim América  São Paulo      1200        4
#
#       Banheiros  Vagas  Valor_anuncio  Valor_mm  Valor_m2  ...  V003  V004  \
# 54            3      2       13000.00      0.01     65.00  ...  3.13  2.87
# 89            4     10    37000000.00     37.00  48941.80  ...  3.13  2.87
# 1032          4     25    65000000.00     65.00  54166.67  ...  3.57  3.01
# 3521         10     20    55000000.00     55.00  30286.34  ...  3.57  3.01
# 3896          6     24    65000000.00     65.00  54166.67  ...  3.57  3.01
#
#          V005          V006     V007          V008     V009         V010  \
# ...

# %%
dados_vendas_censo.drop(dados_vendas_censo.query("Valor_anuncio > 30000000 | Valor_anuncio < 100000").index, inplace= True)
plt.figure(figsize=(10,8))
box5 = sns.boxplot(data = dados_vendas_censo, y = "Valor_anuncio")
plt.show()

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = dados_vendas_censo, x="Valor_anuncio", y="Valor_m2")
plt.show()

# %%
#Calculando correlação entre variáveis.

dados_vendas_censo.corr()
# Out:
#                 Metragem  Quartos  Banheiros  Vagas  Valor_anuncio  Valor_mm  \
# Metragem            1.00     0.23       0.23   0.27           0.30      0.30
# Quartos             0.23     1.00       0.55   0.42           0.37      0.37
# Banheiros           0.23     0.55       1.00   0.46           0.47      0.47
# Vagas               0.27     0.42       0.46   1.00           0.48      0.48
# Valor_anuncio       0.30     0.37       0.47   0.48           1.00      1.00
# Valor_mm            0.30     0.37       0.47   0.48           1.00      1.00
# Valor_m2            0.06     0.12       0.22   0.15           0.70      0.70
# latitude           -0.09    -0.01      -0.03  -0.04           0.02      0.02
# longitude          -0.13    -0.19      -0.25  -0.19          -0.21     -0.21
# Situacao_setor      0.48    -0.01      -0.03  -0.01          -0.00     -0.00
# V001               -0.13    -0.18      -0.22  -0.21          -0.22     -0.22
# ...

# %% [markdown]
# Número entre -1 e 1 que -1 indica inversamente proporcional e 1 é proporcional, 0 quer dizer que não tem correlação entre as variáveis.

# %% [markdown]
# > Correlação não implica em Consequência e causa. É diferente, tomar cuidado.

# %% [markdown]
# Um link citado durante a aula que brinca com a ideia de correlação: [Spurious Correlations](https://www.tylervigen.com/spurious-correlations)

# %%
plt.figure(figsize=(18,8))
mask = np.triu(np.ones_like(dados_vendas_censo.corr(), dtype=bool))
heatmap = sns.heatmap(dados_vendas_censo.corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap="BrBG")
heatmap.set_title("Correlação", fontdict={'fontsize':18},pad=16);

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

#Precisamos treinar nosso modelo, mas primeiro precisamos instanciar nossa regressão linear.
X = dados_vendas_censo[["Metragem"]]
Y = dados_vendas_censo["Valor_anuncio"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 54)
lr = LinearRegression()

# %%
X_train
# Out:
#       Metragem
# 3522       105
# 881        240
# 769        324
# 3364       484
# 4674       103
# ...        ...
# 3558       397
# 3994       224
# 5432       238
# 4044       300
# 948        186
#
# [3977 rows x 1 columns]

# %%
Y_train
# Out:
# 3522    692000.00
# 881    1490000.00
# 769    2100000.00
# 3364   6700000.00
# 4674    622500.00
#           ...
# 3558   4280000.00
# 3994   1500000.00
# 5432   2300000.00
# 4044   1600000.00
# 948    3280000.00
# Name: Valor_anuncio, Length: 3977, dtype: float64

# %%
lr
# Out:
# LinearRegression()

# %% [markdown]
# Treinaremos o modelo em cima da Metragem:

# %%
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_predict_test = lr.predict(X_test)
Y_predict_train = lr.predict(X_train)

# %%
Y_train
# Out:
# 3522    692000.00
# 881    1490000.00
# 769    2100000.00
# 3364   6700000.00
# 4674    622500.00
#           ...
# 3558   4280000.00
# 3994   1500000.00
# 5432   2300000.00
# 4044   1600000.00
# 948    3280000.00
# Name: Valor_anuncio, Length: 3977, dtype: float64

# %%
Y_test
# Out:
# 172    4500000.00
# 4513    345000.00
# 4865    800000.00
# 4979   4000000.00
# 1255   5100000.00
#           ...
# 5240   1600000.00
# 4472    580000.00
# 3291   2200000.00
# 432    1500000.00
# 2455   2800000.00
# Name: Valor_anuncio, Length: 1326, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error, r2_score

#Respostas do modelo para o teste
mean_absolute_error(Y_test, Y_predict_test)
# Out:
# 1770626.9062636306

# %%
#Respostas para o train
mean_absolute_error(Y_train, Y_predict_train)
# Out:
# 1825220.3034549057

# %%
X = dados_vendas_censo[["Metragem", "Quartos", "Banheiros",
                        "Vagas","latitude", "longitude", "Situacao_setor", "V001",
                        "V002", "V003","V004", "V005", "V006","V007", "V008", "V009", "V010",
                        "V011", "V012"]]

Y = dados_vendas_censo["Valor_anuncio"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 54)
lr.fit(X_train, Y_train)
Y_predict_test = lr.predict(X_test)
Y_predict_train = lr.predict(X_train)

mean_test = mean_absolute_error(Y_test, Y_predict_test)
mean_train = mean_absolute_error(Y_train, Y_predict_train)
r2_test = r2_score(Y_test, Y_predict_test)
r2_train = r2_score(Y_train, Y_predict_train)

# %%
mean_test
# Out:
# 1333549.334230695

# %%
mean_train
# Out:
# 1336869.560006686

# %%
r2_test
# Out:
# 0.40346952190104723

# %%
r2_train
# Out:
# 0.4284216741510193

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x=Y_test, y=Y_predict_test)
# Out:
# <AxesSubplot:xlabel='Valor_anuncio'>

# %% [markdown]
# ## Desafio1: Adicionar o valor "Real" do m2 do imóvel.

# %% [markdown]
# ## Desafio2: Testar outo modelos de regressão linear.

# %% [markdown]
# ## Desafio3: Criar um modelo baseline com as features originais

# %% [markdown]
# ## Desafio4: Trabalhar um pouco mais os dados e criar novas variáveis.

# %% [markdown]
# ## Desafio5 : Testas as predições para casos reais.

# %% [markdown]
# ## Projeto Final: Criar um projeto com os resultados da imersão.
# Deixar mais limpos as informações, colocar textos explicando os detalhes do que está acontecendo em cada um dos dados.
# Escrever isso e o passo a passo.
#
# Depois de colocar no Github, depois postar isso no linkedin.
